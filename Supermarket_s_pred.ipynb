# %% [markdown]
# ### **Supermarket Sales Prediction using Supervised Learning**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import scipy as sp
import warnings
import datetime
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
from sklearn.linear_model import LinearRegression

# %%
data = '/content/drive/MyDrive/Ascend/Colab Notebooks/supermarket_sales - Sheet1.csv'
df = pd.read_csv(data)
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df = df.drop(['Invoice ID', 'Date', 'Time'], axis=1)
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total      Payment    cogs  \
# 0         74.69         7  26.1415   548.9715      Ewallet  522.83
# ...

# %%
df.dtypes
# Out:
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df.describe(include='all')
# Out:
#        Branch    City Customer type  Gender         Product line   Unit price  \
# count    1000    1000          1000    1000                 1000  1000.000000
# unique      3       3             2       2                    6          NaN
# top         A  Yangon        Member  Female  Fashion accessories          NaN
# freq      340     340           501     501                  178          NaN
# mean      NaN     NaN           NaN     NaN                  NaN    55.672130
# std       NaN     NaN           NaN     NaN                  NaN    26.494628
# min       NaN     NaN           NaN     NaN                  NaN    10.080000
# 25%       NaN     NaN           NaN     NaN                  NaN    32.875000
# 50%       NaN     NaN           NaN     NaN                  NaN    55.230000
# 75%       NaN     NaN           NaN     NaN                  NaN    77.935000
# max       NaN     NaN           NaN     NaN                  NaN    99.960000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Branch                   1000 non-null   object
#  1   City                     1000 non-null   object
#  2   Customer type            1000 non-null   object
#  3   Gender                   1000 non-null   object
#  4   Product line             1000 non-null   object
#  5   Unit price               1000 non-null   float64
#  6   Quantity                 1000 non-null   int64
#  7   Tax 5%                   1000 non-null   float64
#  8   Total                    1000 non-null   float64
#  9   Payment                  1000 non-null   object
#  10  cogs                     1000 non-null   float64
#  11  gross margin percentage  1000 non-null   float64
#  12  gross income             1000 non-null   float64
#  13  Rating                   1000 non-null   float64
# ...

# %%
df.dtypes
# Out:
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Payment', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.hist(figsize=(20,14))
plt.show()

# %%
plt.style.use("default")
plt.figure(figsize=(5,5))
sns.barplot(x="Rating", y="Unit price", data=df[170:180])
plt.title("Rating vs Unit Price",fontsize=15)
plt.xlabel("Rating")
plt.ylabel("Unit Price")
plt.show()

# %%
df.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Payment', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
plt.style.use("default")
plt.figure(figsize=(5,5))
sns.barplot(x="Rating", y="Gender", data=df[170:180])
plt.title("Rating vs Gender",fontsize=15)
plt.xlabel("Rating")
plt.ylabel("Gender")
plt.show()

# %%
list_1=list(df.columns)

# %%
list_cate=[]
for i in list_1:
    if df[i].dtype=='object':
        list_cate.append(i)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in list_cate:
    df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#      Branch  City  Customer type  Gender  Product line  Unit price  Quantity  \
# 0         0     2              0       0             3       74.69         7
# 1         2     1              1       0             0       15.28         5
# 2         0     2              1       1             4       46.33         7
# 3         0     2              0       1             3       58.22         8
# 4         0     2              1       1             5       86.31         7
# ..      ...   ...            ...     ...           ...         ...       ...
# 995       2     1              1       1             3       40.35         1
# 996       1     0              1       0             4       97.38        10
# 997       0     2              0       1             2       31.84         1
# 998       0     2              1       1             4       65.82         1
# 999       0     2              0       0             1       88.34         7
#
# ...

# %%
y=df['Gender']
x=df.drop('Gender',axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)

# %%
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 800
# 200
# 800
# 200

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)

knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred=knn.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",knn.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.52      0.57      0.55       100
#            1       0.53      0.48      0.50       100
#
#     accuracy                           0.53       200
#    macro avg       0.53      0.52      0.52       200
# weighted avg       0.53      0.53      0.52       200
#
# Confusion Matrix:
#  [[57 43]
#  [52 48]]
# Training Score:
#  66.0

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred=svc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",svc.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.51      0.44      0.47       100
#            1       0.50      0.57      0.54       100
#
#     accuracy                           0.51       200
#    macro avg       0.51      0.51      0.50       200
# weighted avg       0.51      0.51      0.50       200
#
# Confusion Matrix:
#  [[44 56]
#  [43 57]]
# Training Score:
#  54.37499999999999

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=6, random_state=123,criterion='entropy')

dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, random_state=123)

# %%
y_pred=dtree.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",dtree.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.54      0.61      0.57       100
#            1       0.55      0.47      0.51       100
#
#     accuracy                           0.54       200
#    macro avg       0.54      0.54      0.54       200
# weighted avg       0.54      0.54      0.54       200
#
# Confusion Matrix:
#  [[61 39]
#  [53 47]]
# Training Score:
#  64.875

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",rfc.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.53      0.49      0.51       100
#            1       0.52      0.56      0.54       100
#
#     accuracy                           0.53       200
#    macro avg       0.53      0.53      0.52       200
# weighted avg       0.53      0.53      0.52       200
#
# Confusion Matrix:
#  [[49 51]
#  [44 56]]
# Training Score:
#  100.0

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#      Actual  Predicted
# 993       1          0
# 859       0          0
# 298       1          1
# 553       1          1
# 672       0          0
# ..      ...        ...
# 679       1          0
# 722       1          1
# 215       1          0
# 653       1          0
# 150       0          0
#
# [200 rows x 2 columns]

# %% [markdown]
# Kesimpulan:
# Akurasi pada algoritma tertinggi ditunjukkan oleh algoritma 'Random Forest Classifier' yang memiliki nilai sempurna atau 100%. Sedangkan di posisi kedua ada algoritma 'KNN(K-Neighbors Classifier)' dengan akurasi 66% dan di posisi ketiga adalah algoritma 'Decision Tree' dengan akurasi 64% dan terakhir algoritma 'SVM(Support Vector Machine)' dengan akurasi 54%.
